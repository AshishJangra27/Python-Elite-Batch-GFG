# %%
str("&")
# Out:
# '&'

# %%
chr_asci = {"A" : 65 , "B" : 66}
asci_chr = {65  : "A", 66 : "B"}

# %%
l = []

for i in a:
    if 'geeksforgeeks' in i.split(" ")[0].split("</a>")[0].split("</span>")[0]:
        l.append("https:"+i.split(" ")[0].split("</a>")[0].split("</span>")[0])

# %%
len(l)
# Out:
# 765

# %%
l = list(set(l))

# %%
len(l)
# Out:
# 643

# %%
765 - 643
# Out:
# 122

# %%
l
# Out:
# ['https://www.geeksforgeeks.org/java/?ref=shm',
#  'https://www.geeksforgeeks.org/privacy-policy/?ref=footer',
#  'https://www.geeksforgeeks.org/count-of-substrings-with-equal-ratios-of-0s-and-1s-till-ith-index-in-given-binary-string/"',
#  'https://www.geeksforgeeks.org/count-of-substrings-with-equal-ratios-of-0s-and-1s-till-ith-index-in-given-binary-string/',
#  'https://videocdn.geeksforgeeks.org/geeksforgeeks/LanguageTranslatorUsingGoogleAPIinPython/LanguageTranslatorUsingGoogleAPIinPython20211105203021-small.png"',
#  'https://www.geeksforgeeks.org/ugc-net-cs-notes-according-to-syllabus-of-paper-iii-core-group/?ref=ghm"',
#  'https://www.geeksforgeeks.org/cbse-class-9-maths-notes/?ref=ghm"',
#  'https://in.linkedin.com/company/geeksforgeeks"',
#  'https://www.geeksforgeeks.org/maximize-score-by-rearranging-array-such-that-absolute-difference-of-first-and-last-element-is-minimum/"',
#  'https://www.geeksforgeeks.org/videos/watchlist/?ref=ghm',
# ...

# %%
for i in l:
    fd = open('links.txt','a')
    fd.write(i+'\n')
    fd.close()

# %%
# !ls
# Out:
# $RECYCLE.BIN
# Intel
# Recruiting Chatbot - Displaying Job Roles.mov
# Recruiting Chatbot - Final.mov
# Web Scrapping.ipynb
# desktop.ini
# links.txt
# test.txt
